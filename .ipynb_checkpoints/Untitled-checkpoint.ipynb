# %%
import ollama

response = ollama.chat(
    model="llama3.2",
    messages=[{"role": "user", "content": "Say hello and tell me what you are in one sentence."}]
)

print(response['message']['content'])
# Out:
# Hello, I'm an AI assistant designed to provide information and assist with tasks through text-based conversations.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

long_conversation = """
User asked about their project deadline: The science project is due on March 20th.
User mentioned their teacher's name: The teacher's name is Mr. Johnson.
User said their partner's name: Their project partner is named Sarah.
User mentioned the project topic: The project is about renewable energy.
User shared their school name: They go to Foothill High School.
User mentioned their grade: They are in 10th grade.
User said their favorite part: Their favorite part of the project is the solar panel section.
User mentioned a concern: They are worried about the presentation on March 21st.
User shared a fun fact: Sarah is really good at making slides.
User mentioned their goal: They want to get an A on the project.
"""

splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
chunks = splitter.split_text(long_conversation)
print(f"Created {len(chunks)} chunks:")
for i, chunk in enumerate(chunks):
    print(f"  Chunk {i+1}: {chunk[:60]}...")

#The problem is that this takes very long time, around 1-2 miunutes
# Out:
# Created 10 chunks:
#   Chunk 1: User asked about their project deadline: The science project...
#   Chunk 2: User mentioned their teacher's name: The teacher's name is M...
#   Chunk 3: User said their partner's name: Their project partner is nam...
#   Chunk 4: User mentioned the project topic: The project is about renew...
#   Chunk 5: User shared their school name: They go to Foothill High Scho...
#   Chunk 6: User mentioned their grade: They are in 10th grade....
#   Chunk 7: User said their favorite part: Their favorite part of the pr...
#   Chunk 8: User mentioned a concern: They are worried about the present...
#   Chunk 9: User shared a fun fact: Sarah is really good at making slide...
#   Chunk 10: User mentioned their goal: They want to get an A on the proj...

# %%
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
vectorstore = Chroma.from_texts(chunks, embeddings)
print("Vector database created!")

query = "What is the project about?"
results = vectorstore.similarity_search(query, k=2)

print(f"\nTop results for: '{query}'")
for i, result in enumerate(results):
    print(f"  Result {i+1}: {result.page_content}")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Vector database created!
#
# Top results for: 'What is the project about?'
#   Result 1: User mentioned the project topic: The project is about renewable energy.
#   Result 2: User mentioned the project topic: The project is about renewable energy.

# %%
def ask_with_rag_scored(question):
    results = vectorstore.similarity_search(question, k=3)
    context = "\n".join([r.page_content for r in results])
    prompt = f"""Answer using ONLY the context below. Be brief - a few words or one sentence max.
If the answer isn't in the context, say "I don't know."

Context:
{context}

Question: {question}
Answer:"""
    response = ollama.chat(
        model="llama3.2",
        options={"temperature": 0},  # 0 = no randomness
        messages=[{"role": "user", "content": prompt}]
    )
    return response['message']['content'].strip()

ask_with_rag("What is the teacher's name?")
ask_with_rag("When is the presentation?")
ask_with_rag("Who is the project partner?")
# Out:
# Question: What is the teacher's name?
# Retrieved context: User mentioned their teacher's name: The teacher's name is Mr. Johnson.
# User mentioned their teacher's name: The teacher's name is Mr. Johnson.
# Answer: The teacher's name is Mr. Johnson.
# --------------------------------------------------
# Question: When is the presentation?
# Retrieved context: User mentioned a concern: They are worried about the presentation on March 21st.
# User mentioned a concern: They are worried about the presentation on March 21st.
# Answer: March 21st.
# --------------------------------------------------
# Question: Who is the project partner?
# Retrieved context: User said their partner's name: Their project partner is named Sarah.
# User said their partner's name: Their project partner is named Sarah.
# Answer: Sarah.
# --------------------------------------------------

# %%
import json

# Load the dataset
with open("train-v1.1.json") as f:
    squad = json.load(f)

passages = []
qa_pairs = []

for article in squad["data"][:5]: 
    for paragraph in article["paragraphs"]:
        passages.append(paragraph["context"])
        for qa in paragraph["qas"][:2]: 
            qa_pairs.append({
                "question": qa["question"],
                "answer": qa["answers"][0]["text"] 
            })

print(f"Loaded {len(passages)} passages")
print(f"Loaded {len(qa_pairs)} Q&A pairs")
print("\nExample Q&A:")
print(f"Q: {qa_pairs[0]['question']}")
print(f"A: {qa_pairs[0]['answer']}")
# Out:
# Loaded 217 passages
# Loaded 431 Q&A pairs
#
# Example Q&A:
# Q: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# A: Saint Bernadette Soubirous

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

# Split passages into chunks and store in ChromaDB
splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

all_chunks = []
for passage in passages:
    chunks = splitter.split_text(passage)
    all_chunks.extend(chunks)

vectorstore = Chroma.from_texts(all_chunks, embeddings)
print(f"Stored {len(all_chunks)} chunks in ChromaDB")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Stored 1127 chunks in ChromaDB

# %%
def ask_baseline(question):
    response = ollama.chat(
        model="llama3.2",
        messages=[{"role": "user", "content": f"Answer this question in a few words only: {question}"}]
    )
    return response['message']['content'].strip()

def ask_with_rag_scored(question):
    results = vectorstore.similarity_search(question, k=3)
    context = "\n".join([r.page_content for r in results])
    prompt = f"""Answer using only the context below. Be brief and concise.
If the answer isn't in the context, say "I don't know."
Context:
{context}
Question: {question}
Answer:"""
    response = ollama.chat(
        model="llama3.2",
        options={"temperature": 0},
        messages=[{"role": "user", "content": prompt}]
    )
    return response['message']['content'].strip()

test_pairs = qa_pairs[:10]
baseline_scores = []
rag_scores = []

print("Running tests... this will take a minute\n")
print(f"{'Question':<50} {'Correct Answer':<30} {'Baseline':<30} {'RAG':<30}")
print("-" * 140)

for qa in test_pairs:
    q = qa["question"]
    correct = qa["answer"].lower()
    
    baseline_ans = ask_baseline(q)
    rag_ans = ask_with_rag_scored(q)
    
    baseline_correct = 1 if correct in baseline_ans.lower() else 0
    rag_correct = 1 if correct in rag_ans.lower() else 0
    
    baseline_scores.append(baseline_correct)
    rag_scores.append(rag_correct)
    
    print(f"{q[:48]:<50} {correct[:28]:<30} {baseline_ans[:28]:<30} {rag_ans[:28]:<30}")

print("\n" + "=" * 140)
print(f"BASELINE SCORE: {sum(baseline_scores)}/10")
print(f"RAG SCORE:      {sum(rag_scores)}/10")
print(f"IMPROVEMENT:    +{sum(rag_scores) - sum(baseline_scores)} questions answered correctly")
# Out:
# Running tests... this will take a minute
#
# Question                                           Correct Answer                 Baseline                       RAG
# --------------------------------------------------------------------------------------------------------------------------------------------
# To whom did the Virgin Mary allegedly appear in    saint bernadette soubirous     Bernard Soubirous.             Saint Bernadette Soubirous.
# What is in front of the Notre Dame Main Building   a copper statue of christ      Rivière Seine.                 I don't know.
# When did the Scholastic Magazine of Notre dame b   september 1876                 1924                           September 1876.
# How often is Notre Dame's the Juggler published?   twice                          I couldn't find any informat   The Juggler is published twi
# Where is the headquarters of the Congregation of   rome                           South Bend, Indiana.           Rome.
# What is the primary seminary of the Congregation   moreau seminary                Concordia Seminary.            Moreau Seminary.
# How many BS level degrees are offered in the Col   eight                          I don't have that informatio   Eight.
# In what year was the College of Engineering at N   1920                           1887 (not officially named u   I don't know. The context on
# What entity provides help with the management of   learning resource center       University Ombuds Office       I don't know.
# How many colleges for undergraduates are at Notr   five                           There is one undergraduate c   There are 5 colleges for und
#
# ============================================================================================================================================
# BASELINE SCORE: 0/10
# RAG SCORE:      7/10
# IMPROVEMENT:    +7 questions answered correctly
